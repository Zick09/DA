# %%
#установка библиотеки
# !pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in c:\users\admin\anaconda3\lib\site-packages (2.8.6)

# %%
#проверка подключения PostgreSQL 
import psycopg2
import pandas as pd
import matplotlib.pyplot as plt

DB_HOST = '52.157.159.24'

#####################
#!введите свои реквизиты!

DB_USER = 'student16'
DB_USER_PASSWORD = 'student16_password'
DB_NAME = 'sql_ex_for_student16'

conn = psycopg2.connect(host=DB_HOST, user=DB_USER, password=DB_USER_PASSWORD, dbname=DB_NAME)

# %%
# task7 (lesson4)
# По предыдущему iew (count_products_by_makers) сделать график в colab (X: maker, y: count)

# %%
request = 'select * from count_products_by_makers'
df = pd.read_sql_query(request, conn)

# %%
x = df.iloc[:,0]
y = df.iloc[:,1]
plt.plot(x,y)
plt.xlabel('maker')
plt.ylabel('count')
plt.show()

# %%
# task11 (lesson4)
# Корабли: По предыдущему view (sunk_ships_by_classes) сделать график в colab (X: class, Y: count)

# %%
request = 'select * from sunk_ships_by_classes'
df = pd.read_sql_query(request, conn)

# %%
x = df.iloc[:,0]
y = df.iloc[:,1]
plt.scatter(x,y)
plt.xlabel('class')
plt.ylabel('count')
plt.show()

# %%
# task13 (lesson4)
# Корабли: Сделать график в colab по таблице classes с количеством классов по странам (X: country, Y: count)

# %%
request = 'select country, count(*) from classes group by country'
df = pd.read_sql_query(request, conn)

# %%
x = df.iloc[:,0]
y = df.iloc[:,1]
plt.plot(x,y)
plt.xlabel('country')
plt.ylabel('count')
plt.show()

# %%
# task16 (lesson4)
# Корабли: Построить график с количеством запущенных на воду кораблей и годом запуска (X: year, Y: count)

# %%
request = 'select launched, count(*) from ships group by launched order by launched'
df = pd.read_sql_query(request, conn)

# %%
x = df.iloc[:,0]
y = df.iloc[:,1]
plt.plot(x,y)
plt.xlabel('launched')
plt.ylabel('count')
plt.show()
